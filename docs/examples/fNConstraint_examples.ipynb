# %% [markdown]
# # Examples for IGM $f(N)$ constraints (v1.1)

# %%
# %matplotlib inline

# %%
# imports
try:
    import seaborn as sns; sns.set_style("white")
except:
    pass

import time
import imp

import bokeh
from bokeh.io import output_notebook, show, hplot, output_file
from bokeh.plotting import figure
from bokeh.models import Range1d

output_notebook()

from pyigm.fN.fnmodel import FNModel
from pyigm.fN.constraints import FNConstraint

from pyigm.fN import tau_eff as teff

pyigm_path = imp.find_module('pyigm')[1]
# Out:
# /Users/xavier/anaconda/lib/python2.7/site-packages/matplotlib/__init__.py:872: UserWarning: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))
#     <div class="bk-banner">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="68326374-87d3-4355-841c-f6a08bfc18ac">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# ## Load

# %% [markdown]
# ### Vanilla constraints

# %%
fn_file = pyigm_path+'/data/fN/fn_constraints_z2.5_vanilla.fits'
k13r13_file = pyigm_path+'/data/fN/fn_constraints_K13R13_vanilla.fits'
n12_file = pyigm_path+'/data/fN/fn_constraints_N12_vanilla.fits'

# %%
#reload(fNc)
all_fN_cs = FNConstraint.from_fitsfile([fn_file,k13r13_file, n12_file])

# %%
len(all_fN_cs)
# Out:
# 8

# %% [markdown]
# ### Remove K02

# %%
fN_cs = [fN_c for fN_c in all_fN_cs if ((fN_c.ref != 'K02') & (fN_c.ref != 'PW09'))]
fN_dtype = [fc.fN_dtype for fc in fN_cs]
fN_cs
# Out:
# [<FNConstraint: fN_SLLS zeval=2.51004, ref=OPB07>,
#  <FNConstraint: LLS_\tlox zeval=2.22584, ref=OPW12>,
#  <FNConstraint: MFP_\lmfp zeval=2.44, ref=OPW13>,
#  <FNConstraint: teff_\tlya zeval=2.4, ref=K05>,
#  <FNConstraint: fN_Lya Forest zeval=2.37, ref=K13R13>,
#  <FNConstraint: fN_DLA zeval=2.5, ref=N12>]

# %% [markdown]
# ## Plot $f(N)$

# %% [markdown]
# ### $f(N)$ Model

# %%
fN_model = FNModel.default_model()
# Out:
# Using P14 spline values to generate a default model
# Loading: /Users/xavier/local/Python/pyigm/pyigm/data/fN/fN_spline_z24.fits.gz

# %% [markdown]
# ### Data dict

# %%
data_dict = dict(Nbin=[], fN=[], ref=[], pcolor=[], zeval=[])

# %%
clrs = ['blue', 'green', 'red', 'purple']
cnt=0
for fN_c in fN_cs: 
    if fN_c.fN_dtype == 'fN':
        # Length
        ip = range(fN_c.data['NPT'])
        val = np.where(fN_c.data['FN'][ip] > -90)[0]
        npt = len(val)
        # Add in
        if npt > 0:
            ipv = np.array(ip)[val]
            data_dict['Nbin'] += list(np.median(fN_c.data['BINS'][:,ipv],0))
            #xerror = [ fN_c.data['BINS'][1,ipv]-xval, xval-fN_c.data['BINS'][0,ipv] ]
            #yerror = [ fN_c.data['SIG_FN'][1,ipv], fN_c.data['SIG_FN'][0,ipv] ] # Inverted!
            data_dict['fN'] += list(fN_c.data['FN'][ipv])
            data_dict['ref'] += [fN_c.ref]*npt
            data_dict['pcolor'] += [clrs[cnt]]*npt
            data_dict['zeval'] += [fN_c.zeval]*npt
            cnt += 1

# %%
plot_source = bokeh.models.ColumnDataSource(data_dict)

# %%
if fN_model is not None: 
    xplt = 12.01 + 0.01*np.arange(1100)
    line_dict = dict(xplt=xplt,
                     yplt=fN_model.evaluate(xplt, 2.4).flatten(),
                     ref=['P14']*1100, zeval=[fN_model.zpivot]*1100)
    model_source = bokeh.models.ColumnDataSource(line_dict)

# %%
p = bokeh.plotting.figure(tools="reset, hover, tap, resize, wheel_zoom, pan",
                          title="f(N)",
                          x_axis_label="log N_HI",
                          y_axis_label="log f(N)")
#
if fN_model is not None:
    p.line("xplt", "yplt", source=model_source, color='black', line_width=2, legend='P14')
# plot our data
data = p.scatter("Nbin", "fN", 
          source=plot_source, 
          color="pcolor", 
          size=8, legend='data')
# print useful data when you hover
hover = p.select(bokeh.models.HoverTool)
hover.tooltips = {"Ref"    : "@ref",
                  "redshift" : "@zeval"}
#
show(p)
# Out:
#     <div class="plotdiv" id="ad4af36e-74af-48ca-be5a-5826adf91382"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("ad4af36e-74af-48ca-be5a-5826adf91382");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'ad4af36e-74af-48ca-be5a-5826adf91382' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"54ad804f-2c43-4433-adfd-e9094b690ab1":{"roots":{"references":[{"attributes":{"dimension":1,"plot":{"id":"3c60f896-081e-43ac-946a-64f40fc9e4d9","subtype":"Figure","type":"Plot"},"ticker":{"id":"d7859da2-7ca9-4c5d-80c1-129eba65d450","type":"BasicTicker"}},"id":"fd786aa6-3e54-46c6-9e0a-873c2ca09cbe","type":"Grid"},{"attributes":{"plot":{"id":"3c60f896-081e-43ac-946a-64f40fc9e4d9","subtype":"Figure","type":"Plot"}},"id":"533d2ec4-d0fd-4f44-9cf2-6318e3607e96","type":"ResetTool"},{"attributes":{"plot":{"id":"3c60f896-081e-43ac-946a-64f40fc9e4d9","subtype":"Figure","type":"Plot"}},"id":"827d50b2-e5a6-417a-8c2e-fa3d9c49477e","type":"PanTool"},{"attributes":{},"id":"2bb2d214-ee6d-4b36-a092-8d820cfff04b","type":"BasicTickFormatter"},{"attributes":{"data_source":{"id":"d13178f8-aaf8-4c87-b959-26480e44e833","type":"ColumnDataSource"},"glyph":{"id":"79927338-4cfa-4b74-88b2-f0a7e38cd905","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"2a4465a5-4149-4477-b109-caa61637907e","type":"Line"},"selection_glyph":null},"id":"3d27b63a-adf6-4c21-b4c9-8019049d01f8","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"3c60f896-081e-43ac-946a-64f40fc9e4d9","subtype":"Figure","type":"Plot"}},"id":"eaeb2c91-a832-4b81-91f9-2649d129c15f","type":"WheelZoomTool"},{"attributes":{"callback":null,"plot":{"id":"3c60f896-081e-43ac-946a-64f40fc9e4d9","subtype":"Figure","type":"Plot"}},"id":"77d2fc5c-e795-40b7-a3eb-4ebca0aa209e","type":"TapTool"},{"attributes":{"plot":{"id":"3c60f896-081e-43ac-946a-64f40fc9e4d9","subtype":"Figure","type":"Plot"},"ticker":{"id":"9767652f-8436-446d-9390-10e90d208828","type":"BasicTicker"}},"id":"bb76070b-c06f-4a1e-8c3e-3413b5738dc4","type":"Grid"},{"attributes":{"callback":null,"column_names":["ref","xplt","zeval","yplt"],"data":{"ref":["P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P14","P ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[14]</strong>&gt;</code></p>

# %% [markdown]
# ## Plot other constraints

# %%
con_dict = dict(xval=[], value=[], error=[], ftype=[], pcolor=[], ref=[], zeval=[])

# %% [markdown]
# ### $\tau_{\rm eff}$

# %%
itau = fN_dtype.index('teff') # Passes back the first one

# %%
fN_cs[itau].data['TEFF']
# Out:
# 0.19778812

# %%
itau = fN_dtype.index('teff')     
con_dict['value'] += [float(fN_cs[itau].data['TEFF'])]
D_A = 1. - np.exp(-1. * con_dict['value'][0])
SIGDA_LIMIT = 0.1  # Allows for systemtics and b-value uncertainty
con_dict['error'] += [np.max([fN_cs[itau].data['SIG_TEFF'], (SIGDA_LIMIT*con_dict['value'][0])])]
con_dict['pcolor'] += ['blue']
con_dict['ref'] += [fN_cs[itau].ref]
con_dict['zeval'] += [fN_cs[itau].zeval]
con_dict['xval'] += [1]
con_dict['ftype'] += ['tau_eff']

# %% [markdown]
# ### $\ell(X)$

# %%
iLLS = fN_dtype.index('LLS') # Passes back the first one
con_dict['value'] += [fN_cs[iLLS].data['LX']]
con_dict['error'] += [fN_cs[iLLS].data['SIG_LX']]
con_dict['pcolor'] += ['green']
con_dict['ref'] += [fN_cs[iLLS].ref]
con_dict['zeval'] += [fN_cs[iLLS].zeval]
con_dict['xval'] += [2]
con_dict['ftype'] += ['l(X)']

# %% [markdown]
# ### $\lambda_{\rm mfp}$

# %%
iMFP = fN_dtype.index('MFP') 
con_dict['value'] += [fN_cs[iMFP].data['MFP']/500]
con_dict['error'] += [fN_cs[iMFP].data['SIG_MFP']/500]
con_dict['pcolor'] += ['red']
con_dict['ref'] += [fN_cs[iMFP].ref]
con_dict['zeval'] += [fN_cs[iMFP].zeval]
con_dict['xval'] += [3]
con_dict['ftype'] += ['MFP/(500 Mpc)']

# %% [markdown]
# ### Model

# %%
x_model = [1,2,3]
y_model = [None]*3

# %%
# teff
y_model[0] = teff.lyman_ew(1215.6701*(1+fN_cs[itau].zeval), 
                           fN_cs[itau].zeval+0.1, fN_model, 
                           NHI_MIN=fN_cs[itau].data['NHI_MNX'][0],
                           NHI_MAX=fN_cs[itau].data['NHI_MNX'][1])
# Out:
# Loading abundances from Asplund2009
# Abundances are relative by number on a logarithmic scale with H=12
# WARNING: UnitsWarning: The unit 'Angstrom' has been deprecated in the FITS standard. Suggested: 10**-1 nm. [astropy.units.format.utils]
# /Users/xavier/local/Python/pyigm/pyigm/fN/tau_eff.py:222: VisibleDeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   restEW = interpolate.splev(lgNval, EW_spline['tck'][idx], der=0)

# %%
# l(X)
y_model[1] = fN_model.calculate_lox(fN_cs[iLLS].zeval, 
                                    17.19+np.log10(fN_cs[iLLS].data['TAU_LIM']), NHI_max=22.)

# %%
# MFP
y_model[2] = fN_model.mfp(fN_cs[iMFP].zeval).value / 500.

# %%
x_model, y_model
# Out:
# ([1, 2, 3], [0.19818321669381098, 0.33534482853058251, 0.5142051134453323])

# %% [markdown]
# ### Plot

# %%
con_source = bokeh.models.ColumnDataSource(con_dict)

# %%
p = bokeh.plotting.figure(tools="reset, hover, tap, resize, wheel_zoom, pan",
                          title="Integral Constraints",
                          y_axis_label="Value")
# Constraints
p.scatter("xval", "value", source=con_source, color="pcolor", size=7)
err_xs = []
err_ys = []
for x, y, yerr in zip(con_dict['xval'], con_dict['value'], con_dict['error']):
    err_xs.append((x, x))
    err_ys.append((y - yerr, y + yerr))
p.multi_line(err_xs, err_ys, color='gray', line_width=2)
#
p.text(con_dict['xval'], [0.]*3, con_dict['ftype'], text_color=con_dict['pcolor'],
      text_align="center")
# Model
p.square(x_model, y_model, color='black', fill_color=None, size=10, line_width=2, legend='Model')
# Hover
hover = p.select(bokeh.models.HoverTool)
hover.tooltips = {"Ref"    : "@ref",
                  "Type"   : "@ftype", 
                  "Value"  : "@value", 
                  "Error"  : "@error", 
                  "redshift" : "@zeval"}
# style
p.xgrid.grid_line_color = None
p.ygrid.grid_line_color = None
p.xaxis.major_label_text_color = None
p.set(x_range=Range1d(0.5,3.5), y_range=Range1d(0.,0.6))
p.legend.orientation = "top_left"
#
show(p)
# Out:
# /Users/xavier/anaconda/lib/python2.7/site-packages/bokeh/core/properties.py:714: BokehDeprecationWarning: bokeh.models.annotations.orientation was deprecated in Bokeh 0.11; please use Legend.location instead
#   super(HasProps, self).__setattr__(name, value)
#     <div class="plotdiv" id="71ee1928-b293-41ed-8fe3-4a90ae1c6c3d"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("71ee1928-b293-41ed-8fe3-4a90ae1c6c3d");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '71ee1928-b293-41ed-8fe3-4a90ae1c6c3d' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"a3eafed1-3631-4b93-bd09-30beff5ea5dc":{"roots":{"references":[{"attributes":{"dimension":1,"plot":{"id":"3c60f896-081e-43ac-946a-64f40fc9e4d9","subtype":"Figure","type":"Plot"},"ticker":{"id":"d7859da2-7ca9-4c5d-80c1-129eba65d450","type":"BasicTicker"}},"id":"fd786aa6-3e54-46c6-9e0a-873c2ca09cbe","type":"Grid"},{"attributes":{"plot":{"id":"3c60f896-081e-43ac-946a-64f40fc9e4d9","subtype":"Figure","type":"Plot"}},"id":"533d2ec4-d0fd-4f44-9cf2-6318e3607e96","type":"ResetTool"},{"attributes":{"callback":null,"end":3.5,"start":0.5},"id":"136ef8b6-cc57-45ee-a270-ca3cb8e81591","type":"Range1d"},{"attributes":{"plot":{"id":"3c60f896-081e-43ac-946a-64f40fc9e4d9","subtype":"Figure","type":"Plot"}},"id":"827d50b2-e5a6-417a-8c2e-fa3d9c49477e","type":"PanTool"},{"attributes":{"formatter":{"id":"70c8b4ce-d925-4784-aacd-5d82d368f0b7","type":"BasicTickFormatter"},"major_label_text_color":{"value":null},"plot":{"id":"be5b05ba-2f4b-4ab2-b43a-55f95f0d1665","subtype":"Figure","type":"Plot"},"ticker":{"id":"bf5ea7a2-82f4-4920-bef5-3d221f05676a","type":"BasicTicker"}},"id":"1afd8e9f-94ab-47fd-b88d-ead63845ef6a","type":"LinearAxis"},{"attributes":{"callback":null,"plot":{"id":"be5b05ba-2f4b-4ab2-b43a-55f95f0d1665","subtype":"Figure","type":"Plot"},"tooltips":[["Type","@ftype"],["redshift","@zeval"],["Ref","@ref"],["Value","@value"],["Error","@error"]]},"id":"792bc878-d89b-4fdd-a290-d20ab193aede","type":"HoverTool"},{"attributes":{"fill_color":{"value":null},"line_width":{"value":2},"size":{"units":"screen","value":10},"x":{"field":"x"},"y":{"field":"y"}},"id":"66b2cabf-6acb-495c-8c76-00919e8ead4b","type":"Square"},{"attributes":{"plot":{"id":"3c60f896-081e-43ac-946a-64f40fc9e4d9","subtype":"Figure","type":"Plot"}},"id":"eaeb2c91-a832-4b81-91f9-2649d129c15f","type":"WheelZoomTool"},{"attributes":{"axis_label":"Value","formatter":{"id":"f9cfa14b-e24d-4f3e-99bb-01834b777944","type":"BasicTickFormatter"},"plot":{"id":"be5b05ba-2f4b-4ab2-b43a-55f95f0d1665","subtype":"Figure","type":"Plot"},"ticker":{"id":"4da29b11-6f24-4e4c-ba36-bbdac2559b44","type":"BasicTicker"}},"id":"74bbe82d-272d-4dfb-8c78-98bb142f5854","type":"LinearAxis"},{"attributes":{"callback":null,"plot":{"id":"3c60f896-081e-43ac-946a-64f40fc9e4d9","subtype":"Figure","type":"Plot"}},"id":"77d2fc5c-e795-40b7-a3eb-4ebca0aa209e","type":"TapTool"},{"attributes":{"below":[{"id":"2b34c72b-6d3e-4c5b-b821-9e6d9afc2776","type":"LinearAxis"}],"left":[{"id":"344aaaa8-49d4-4272-b860-47609411a5f5","type":"LinearAxis"}],"renderers":[{"id":"2b34c72b-6d3e-4c5b-b821-9e6d9afc2776","type":"LinearAxis"},{"id":"bb76070b-c06f-4a1e-8c3e-3413b5738dc4","type":"Grid"},{"id":"344aaaa8-49d4-4272-b860-47609411a5f5","type":"LinearAxis"},{"id":"fd786aa6-3e54-46c6-9e0a-873c2ca09cbe","type":"Grid"},{"id":"7c211f6f-e976-46ba-bc3e-5cfa4f93309a","type":"Legend"},{"id":"3d27b63a-adf6-4c21-b4c9-8019049d01f8","type":"GlyphRenderer"},{"id":"b5e40b3e-4fe7-42bc-99ed-139dfca14ea0","type":"GlyphRenderer"}],"title":"f(N)","tool_events":{"id":"01f702ad-9b35-401a-b75c-284192cb4ec7","type":"ToolEvents"},"tools":[{"id":"533d2ec4-d0fd-4f44-9cf2-6318e3607e96","type":"ResetTool"},{"id":"91e893a6-3c06-47ee-b945-d8ccd4b741d9","type":"HoverTool"},{"id":"77d2fc5c-e795-40b7-a3eb-4ebca0aa209e","type":"TapTool"},{"id":"995cb87a-1e13-43eb-b3a6-86907cab49d9","type":"ResizeTool"},{"id":"eaeb2c91-a832-4b81-91f9-2649d129c15f","type":"WheelZoomTool"},{"id":"827d50b2-e5a6-417a-8c2e-fa3d9c49477e","type":"PanTool"}],"x_range":{"id":"0935f003-ff96-4ef1-a173-8817fc38d74d","type":"DataRange1d"},"y_range":{"id":"4c595d52-6edd-4fcc-840c-e2980212b9a0","type":"DataRange1d"}},"id":"3c60f896-081e-43ac-946a-64f40fc9e4d9","subtype":"Figure","type":"Plot"},{"attributes":{},"id":"bf5ea7a2-82f4-4920-bef5-3d221f05676a","type":"BasicTicker"},{"attributes":{"data_source":{"id":"6ceb8034-6f14-4718-8b08-cfb3ebb60783","type":"ColumnDataSource"},"glyph":{"id":"64db4254-1280-4c95-867d-b4c420f260a5","type":"Text"},"hover_glyph":null,"nonselection_glyph ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[29]</strong>&gt;</code></p>
