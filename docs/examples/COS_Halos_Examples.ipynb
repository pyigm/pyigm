# %% [markdown]
# # COS Halos Examples (useful for an CGM Survey)
#
# See also the CGM_examples Notebook

# %%
# import
from astropy.table import Table
from pyigm.cgm import cos_halos as pch

# %% [markdown]
# ## Load COS-Halos

# %%
cos_halos = pch.COSHalos()
cos_halos.load_sys()#debug=True)

# %% [markdown]
# ## Ion Table for the Survey

# %%
SiIII_tbl = cos_halos.ion_tbl((14,3))

# %%
SiIII_tbl

# %% [markdown]
# ## EW Table for the Survey for a given transition

# %%
trans = 'SiIII 1206'

# %%
tbl = cos_halos.trans_tbl(trans)
tbl

# %% [markdown]
# ## Timing

# %%
import cProfile, profile
from pyigm.cgm import cos_halos as pch

# %%
reload(pch)
#profile.run('ch = pch.COSHalos(debug=True)')
#ch = pch.COSHalos(debug=True)
cProfile.run('ch = pch.COSHalos()')
#%prun -s cumtime 'pch.cosHalos(debug=True)'
# Out:
# WARNING: UnitsWarning: The unit 'Angstrom' has been deprecated in the FITS standard. Suggested: 10**-1 nm. [astropy.units.format.utils]
# WARNING:astropy:UnitsWarning: The unit 'Angstrom' has been deprecated in the FITS standard. Suggested: 10**-1 nm.
# Be patient, using /Users/xavier/Dropbox/COS-Halos-Data/cos-halos_systems.v1.1.tar.gz to load COS-Halos
# Skipping a likely folder: CGM_JSON
# > /Users/xavier/local/Python/pyigm/pyigm/cgm/cgm.py(100)from_dict()
# -> slf = cls(galaxy, igm_sys, **kwargs2)
# (Pdb) idict
# {u'cosmo': u'WMAP9', u'DEC': 0.25808333333333333, u'Name': u'J0226+0015_268_22', u'igm_sys': {u'user': u'xavier', u'vlim': [-600.0, 600.0], u'DEC': 0.2582777777777778, u'kin': {}, u'Name': u'J022614.5+001529.8_z0.227', u'flag_NHI': 1, u'Refs': [], u'NHI': 14.248659133911133, u'zem': 0.0, u'sig_NHI': 0.030700907111167908, u'RA': 36.56041666666667, u'components': {u'FeIII_z0.22744': {u'A': None, u'comment': u'', u'Zion': [26, 3], u'Name': u'FeIII_z0.22744', u'Ej': 0.0, u'zcomp': 0.22743989527225494, u'lines': {u'1122.524': {u'ltype': u'Abs', u'name': u'FeIII 1122', u'analy': {u'flg_limit': 0, u'vlim': {u'value': [156.0, 332.0], u'unit': u'km / s'}, u'datafile': u'', u'name': u'FeIII 1122', u'flg_eye': 0, u'wvlim': {u'value': [0.0, 0.0], u'unit': u'Angstrom'}, u'do_analysis': 1, u'flag_kin': 0}, u'wrest': {u'value': 1122.524, u'unit': u'Angstrom'}, u'attrib': {u'b': {u'value': 0.0, u'unit': u'km / s'}, u'sig_N': {u'value': 1119733684236053.8, u'unit': u'1 / cm2'}, u'flag_EW': 3, u'sig_b': {u'value': 0.0, u'unit': u'km / s'}, u'z': 0.22743989527225494, u'N': {u'value': 54032684473879.586, u'unit': u'1 / cm2'}, u'sig_EW': {u'value': 0.02078643127715843, u'unit': u'Angstrom'}, u'sig_z': 0.0, u'sig_logN': 9.0, u'RA': 36.56041666666667, u'v': {u'value': 0.0, u'unit': u'km / s'}, u'logN': 13.732656544870883, u'EW': {u'value': -0.032712833007258406, u'unit': u'Angstrom'}, u'DEC': 0.2582777777777778, u'flag_origCH': 5, u'sig_v': {u'value': 0.0, u'unit': u'km / s'}, u'flag_N': 3}, u'data': {u'el': 0, u'is_Strong': True, u'wrest': {u'value': 1122.524, u'unit': u'Angstrom'}, u'is_HI': False, u'gk': 7, u'gj': 9, u'nj': 0, u'nk': 0, u'group': 1, u'Ref': u'Morton2003', u'Jj': 0.0, u'Jk': 0.0, u'A': {u'value': 370000000.0, u'unit': u'1 / s'}, u'ion': 3, u'mol': u'', u'Z': 26, u'name': u'FeIII 1122', u'Ek': {u'value': 89084.95, u'unit': u'1 / cm'}, u'Ej': {u'value': 0.0, u'unit': u'1 / cm'}, u'f': 0.0544, u'Am': 0, u'Ex': {u'value': 0.0, u'unit': u'1 / cm'}, u'gamma': {u'value': 370000000.0, u'unit': u'1 / s'}, u'is_EUV': False}}}, u'vlim': [156.0, 332.0], u'sig_logN': 9.0, u'RA': 36.56041666666667, u'logN': 13.732656544870883, u'DEC': 0.2582777777777778, u'flag_N': 3}, u'HI_z0.22744': {u'A': None, u'comment': u'', u'Zion': [1, 1], u'Name': u'HI_z0.22744', u'Ej': 0.0, u'zcomp': 0.22743989527225494, u'lines': {u'1025.7222': {u'ltype': u'Abs', u'name': u'HI 1025', u'analy': {u'flg_limit': 0, u'vlim': {u'value': [0.0, 220.0], u'unit': u'km / s'}, u'datafile': u'', u'name': u'HI 1025', u'flg_eye': 0, u'wvlim': {u'value': [0.0, 0.0], u'unit': u'Angstrom'}, u'do_analysis': 1, u'flag_kin': 0}, u'wrest': {u'value': 1025.7222, u'unit': u'Angstrom'}, u'attrib': {u'b': {u'value': 0.0, u'unit': u'km / s'}, u'sig_N': {u'value': 0.0, u'unit': u'1 / cm2'}, u'flag_EW': 3, u'sig_b': {u'value': 0.0, u'unit': u'km / s'}, u'z': 0.22743989527225494, u'N': {u'value': 0.0, u'unit': u'1 / cm2'}, u'sig_EW': {u'value': 0.0, u'unit': u'Angstrom'}, u'sig_z': 0.0, u'RA': 36.56041666666667, u'v': {u'value': 0.0, u'unit': u'km / s'}, u'EW': {u'value': 0.0, u'unit': u'Angstrom'}, u'DEC': 0.2582777777777778, u'flag_origCH': 2, u'sig_v': {u'value': 0.0, u'unit': u'km / s'}, u'flag_N': 0}, u'data': {u'el': 0, u'is_Strong': True, u'wrest': {u'value': 1025.7222, u'unit': u'Angstrom'}, u'is_HI': True, u'gk': 6, u'gj': 2, u'nj': 0, u'nk': 0, u'group': 1, u'Ref': u'Morton2003', u'Jj': 0.0, u'Jk': 0.0, u'A': {u'value': 167300000.0, u'unit': u'1 / s'}, u'ion': 1, u'mol': u'', u'Z': 1, u'name': u'HI 1025', u'Ek': {u'value': 7492.28344, u'unit': u'1 / cm'}, u'Ej': {u'value': 0.0, u'unit': u'1 / cm'}, u'f': 0.07914, u'Am': 0, u'Ex': {u'value': 0.0, u'unit': u'1 / cm'}, u'gamma': {u'value': 189700000.0, u'unit': u'1 / s'}, u'is_EUV': False}}, u'949.743': {u'ltype': u'Abs', u'name': u'HI 949', u'analy': {u'flg_limit': 0, u'vlim': {u'value': [0.0, 250.0], u'unit': u'km / s'}, u'datafile': u'', u'name': u'HI 949', u'flg_eye': 0, u'wvlim': {u'value': [0.0, 0.0], u'unit': u'Angstrom'}, u'do_anal ...
# (Pdb) idict.keys()
# [u'cosmo', u'DEC', u'Name', u'igm_sys', u'z', u'PA', u'RA', u'rho', u'ang_sep', u'CreationDate', u'galaxy', u'user']

# %%
ss = 3 * u.cm

# %%
ss.put(0,4*ss.unit)

# %%
ss
