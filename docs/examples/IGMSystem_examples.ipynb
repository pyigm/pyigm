# %% [markdown]
# # Some examples with IGMSystems

# %%
# %matplotlib notebook

# %%
# import
from linetools.spectra.xspectrum1d import XSpectrum1D
from pyigm.abssys import igmsys as pyisys
from pyigm.abssys import utils as pyautils

# %% [markdown]
# ## HI System

# %%
hisys = pyisys.HISystem((0.,0.), 4., None, NHI=20.5)

# %%
hisys
# Out:
# <HISystem: HI 00:00:00 00:00:00, 4, NHI=20.5, Z/H=0>

# %% [markdown]
# ### Generate an HI Model

# %%
wave = np.arange(3800., 8000., 0.2)
xspec = XSpectrum1D.from_tuple((wave, np.ones_like(wave), np.ones_like(wave)*0.1))

# %%
himodel, lines = pyautils.hi_model(hisys, xspec, add_lls=True)

# %%
himodel.plot()
# Out:
# <img src="data:image/png;base64,...">
