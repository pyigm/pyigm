# %% [markdown]
# # Examples of Evaluating f(N)  [v1.0]
#
# ##   Here are some additional evaluations of f(N) beyond those in FNModel

# %%
# %matplotlib notebook

# %%
# imports
import imp
from scipy.signal import medfilt

from matplotlib import pyplot as plt

from astropy.table import Table

from pyigm.fN import dla as pyi_fd

pyigm_path = imp.find_module('pyigm')[1]

# %% [markdown]
# ## DLAs

# %% [markdown]
# ### Examine Sanchez-Ramirez et al. 2016  (XQ-100)

# %%
tab7_fil = pyigm_path+'/data/DLA/XQ-100/sramirez16_table7.dat'
sr16_tab7 = Table.read(tab7_fil, format='ascii')

# %%
sr16_tab7[0:3]
# Out:
# <Table length=3>
#    z       Dz   sumDX  nabs ... bmOlci_68.3 bmOhci_68.3 bmOlci_95.0 bmOhci_95.0
# float64 float64 int64 int64 ...   float64     float64     float64     float64
# ------- ------- ----- ----- ... ----------- ----------- ----------- -----------
#    2.15   0.831   965    62 ...       0.506       0.753       0.432       0.983
#    2.16   0.831   997    64 ...       0.494       0.729       0.422       0.948
#    2.17    0.83  1023    66 ...       0.489       0.727       0.422        0.94

# %%
plt.clf()
ax = plt.gca()
ax.plot(sr16_tab7['z'], sr16_tab7['lx'])
plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# #### Median smooth

# %%
lxmed = medfilt(sr16_tab7['lx'], 21)
plt.clf()
ax = plt.gca()
ax.plot(sr16_tab7['z'], lxmed)
plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# ### Use SR16

# %%
reload(pyi_fd)
for z in [1., 2.2, 4., np.array([1,2.5,4])]:
    print('lX={} at z={}'.format(pyi_fd.lX(z), z))
# Out:
# lX=0.0 at z=1.0
# lX=0.06 at z=2.2
# lX=0.084 at z=4.0
# lX=[ 0.     0.06   0.084] at z=[ 1.   2.5  4. ]
